# %%
import pandas as pd

# %%
df = pd.read_excel('/Users/harshith/Desktop/untitled folder 2/interns3.xlsx')

# %%
df = pd.DataFrame(df)

# %%
df
# Out:
#     position                            title  \
# 0          0                      BLR Airport
# 1          1                      BLR Airport
# 2          2                     anshul gupta
# 3          3                 Bangalore Mirror
# 4          4          BLR Airport - Bengaluru
# ..       ...                              ...
# 87        87      In_Sane_Saint - Ashish Jain
# 88        88                       Ravi Handa
# 89        89                    Narendra Modi
# 90        90  Harvesting Farmer Network (HFN)
# 91        91                DashHound - X.com
#
#                                               snippet  \
# 0   Jul 31, 2023 — ... food & beverages, staff ser...
# 1   Aug 3, 2022 — has opened a new outlet at Depar...
# 2   Sep 25, 2023 — Bangalore airport also earns 70...
# 3   Dec 15, 2020 — The Quad retail and food and be...
# 4   Oct 23, 2021 — #BLRAirport for the live screen...
# ..                                                ...
# ...

# %%
df.describe()
# Out:
#        position
# count  92.00000
# mean   45.50000
# std    26.70206
# min     0.00000
# 25%    22.75000
# 50%    45.50000
# 75%    68.25000
# max    91.00000

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 87    False
# 88    False
# 89    False
# 90    False
# 91    False
# Length: 92, dtype: bool

# %%
df=df.drop(columns=['position','title','link','displayed_link','sitelinks'])

# %%
df
# Out:
#                                               snippet  \
# 0   Jul 31, 2023 — ... food & beverages, staff ser...
# 1   Aug 3, 2022 — has opened a new outlet at Depar...
# 2   Sep 25, 2023 — Bangalore airport also earns 70...
# 3   Dec 15, 2020 — The Quad retail and food and be...
# 4   Oct 23, 2021 — #BLRAirport for the live screen...
# ..                                                ...
# 87  Start Up Idea: Flight service from Bangalore A...
# 88  Sep 9, 2022 — 5 years ago, they used to be coo...
# 89  Nov 11, 2022 — Terminal 2 of the Kempegowda In...
# 90  Apr 12, 2020 — Partial movement is allowed for...
# 91  Aug 31, 2023 — Cheers from the International L...
#
#                                             highlighs
# 0   ['food', 'beverages', 'Kempegowda Internationa...
# 1                                            ['food']
# 2         ['Bangalore airport', 'Food and beverages']
# 3   ['food and beverage', 'Kempegowda Internationa...
# ...

# %%
df['highlighs']==''
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 87    False
# 88    False
# 89    False
# 90    False
# 91    False
# Name: highlighs, Length: 92, dtype: bool

# %%
df.to_excel('/Users/harshith/Desktop/untitled folder 2/interns_new.xlsx',index=False)

# %%
df2=pd.read_excel('/Users/harshith/Desktop/untitled folder 2/interns2.xlsx')

# %%
df2=pd.DataFrame(df2)

# %%
df2
# Out:
#     position                                              title  \
# 0          0                            Taj Bangalore - Twitter
# 1          1                Taj Bangalore (@TajBangalore) / ...
# 2          2                                            Aviserv
# 3          3                                            Aviserv
# 4          4                Red Key (@RedKey94155390) / Twitter
# ..       ...                                                ...
# 94        94                               Sunderdeep - Volklub
# 95        95     vishwanath somapur (@vishwanath1241) / Twitter
# 96        96               Musthafa PC (@Musthafa_PC) / Twitter
# 97        97          Blessen Babu (@blessn_official) / Twitter
# 98        98  Bengaluru Airport City receives IGBC Green ......
#
#                                               snippet  \
# 0   May 22, 2019 — Dive into the luxury and unmatc...
# 1   Taj Bangalore is a mere walk away from the Kem...
# ...

# %%
df2=df2.drop(columns=['position','title','link','displayed_link','sitelinks'])

# %%
df2
# Out:
#                                               snippet  \
# 0   May 22, 2019 — Dive into the luxury and unmatc...
# 1   Taj Bangalore is a mere walk away from the Kem...
# 2   Sep 14, 2018 — We're offering a full range of ...
# 3   Sep 14, 2018 — We're offering a full range of ...
# 4   Red Key is a budget-friendly 2-star hotel in B...
# ..                                                ...
# 94  Bangalore Auto Driver. Embedded video. 0:25. 2...
# 95  ⁩ and staff of HBX airport for hospitality at ...
# 96  ... Bangalore factory today, 30th March, at 12...
# 97  #swiggy is down in Bangalore. Image. 1. Blesse...
# 98  Bengaluru Airport City receives IGBC Green Cit...
#
#                                             highlighs
# 0   ['hospitality', 'Bangalore', 'Kempegowda Inter...
# 1   ['Bangalore', 'International Airport', 'hotel'...
# 2                          ['Hospitality', 'airport']
# 3                          ['Hospitality', 'airport']
# ...

# %%
df2.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
#       ...
# 94    False
# 95    False
# 96    False
# 97    False
# 98    False
# Length: 99, dtype: bool

# %%
df2.drop_duplicates()
# Out:
#                                               snippet  \
# 0   May 22, 2019 — Dive into the luxury and unmatc...
# 1   Taj Bangalore is a mere walk away from the Kem...
# 2   Sep 14, 2018 — We're offering a full range of ...
# 4   Red Key is a budget-friendly 2-star hotel in B...
# 5   Hotel Golden Evana provides hotel close to Ban...
# ..                                                ...
# 94  Bangalore Auto Driver. Embedded video. 0:25. 2...
# 95  ⁩ and staff of HBX airport for hospitality at ...
# 96  ... Bangalore factory today, 30th March, at 12...
# 97  #swiggy is down in Bangalore. Image. 1. Blesse...
# 98  Bengaluru Airport City receives IGBC Green Cit...
#
#                                             highlighs
# 0   ['hospitality', 'Bangalore', 'Kempegowda Inter...
# 1   ['Bangalore', 'International Airport', 'hotel'...
# 2                          ['Hospitality', 'airport']
# 4    ['hotel in Bangalore', 'Airport', 'hospitality']
# ...

# %%
df2.dropna(inplace=True)

# %%
df2
# Out:
#                                               snippet  \
# 0   May 22, 2019 — Dive into the luxury and unmatc...
# 1   Taj Bangalore is a mere walk away from the Kem...
# 2   Sep 14, 2018 — We're offering a full range of ...
# 3   Sep 14, 2018 — We're offering a full range of ...
# 4   Red Key is a budget-friendly 2-star hotel in B...
# ..                                                ...
# 94  Bangalore Auto Driver. Embedded video. 0:25. 2...
# 95  ⁩ and staff of HBX airport for hospitality at ...
# 96  ... Bangalore factory today, 30th March, at 12...
# 97  #swiggy is down in Bangalore. Image. 1. Blesse...
# 98  Bengaluru Airport City receives IGBC Green Cit...
#
#                                             highlighs
# 0   ['hospitality', 'Bangalore', 'Kempegowda Inter...
# 1   ['Bangalore', 'International Airport', 'hotel'...
# 2                          ['Hospitality', 'airport']
# 3                          ['Hospitality', 'airport']
# ...

# %%
df2.loc[:,"highlighs"]
# Out:
# 0     ['hospitality', 'Bangalore', 'Kempegowda Inter...
# 1     ['Bangalore', 'International Airport', 'hotel'...
# 2                            ['Hospitality', 'airport']
# 3                            ['Hospitality', 'airport']
# 4      ['hotel in Bangalore', 'Airport', 'hospitality']
#                             ...
# 94                             ['Bangalore', 'airport']
# 95    ['airport', 'hospitality', 'flight', 'Bangalor...
# 96                             ['Bangalore', 'airport']
# 97               ['Bangalore', 'flight', 'hospitality']
# 98                   ['Bengaluru Airport', 'Bengaluru']
# Name: highlighs, Length: 98, dtype: object

# %%
df2.to_excel('/Users/harshith/Desktop/untitled folder 2/interns2_new.xlsx',index=False)

# %%
df3=pd.read_excel('/Users/harshith/Desktop/untitled folder 2/interns1.xlsx')

# %%
df3
# Out:
#     position                                              title  \
# 0          0                                        BLR Airport
# 1          1  Immigration Chaos at Bengaluru Airport. 8 coun...
# 2          2                                Kiran Mazumdar-Shaw
# 3          3                                     Pranava Tandra
# 4          4                                       Harsh Goenka
# ..       ...                                                ...
# 94        94                      Ravi Kumar (@Ravi_Author) / X
# 95        95             卫纳夜格.巴特 Col Vinayak Bhat (Retd) @Raj47
# 96        96  Flyers can bid goodbye to traffic jams and tak...
# 97        97                        تويتر \ Tarang (Tarang_97@)
# 98        98                 تويتر \ Siddharth Behera (imseed@)
#
#                                               snippet  \
# 0   Dec 15, 2022 — Some media have reported that B...
# 1   May 23, 2022 — Immigration Chaos at Bengaluru ...
# ...

# %%
df3=df3.drop(columns=["position","title","link","displayed_link","sitelinks"])

# %%
df3
# Out:
#                                               snippet  \
# 0   Dec 15, 2022 — Some media have reported that B...
# 1   May 23, 2022 — Immigration Chaos at Bengaluru ...
# 2   May 21, 2022 — Pathetic state of immigration a...
# 3   3AM immigration queues at Bangalore Airport. I...
# 4   May 23, 2022 — Scenes in immigration in the Be...
# ..                                                ...
# 94  Entertainment & Recreation Bangalore ravikumar...
# 95  May 16, 2018 — #India #Bengaluru #Bellandur #L...
# 96  Feb 9, 2018 — ... AIRPORT(http://taal.co.in) w...
# 97  The immigration officer at the Ahmd airport no...
# 98  (chennai - Bangalore 6E6137). I ... The great ...
#
#                                             highlighs
# 0           ['BLR Airport', 'Immigration', 'airport']
# 1                ['Immigration', 'Bengaluru Airport']
# 2   ['immigration', 'Bengaluru International Airpo...
# 3                ['immigration', 'Bangalore Airport']
# ...

# %%
df3.dropna(inplace=True)

# %%
df3
# Out:
#                                               snippet  \
# 0   Dec 15, 2022 — Some media have reported that B...
# 1   May 23, 2022 — Immigration Chaos at Bengaluru ...
# 2   May 21, 2022 — Pathetic state of immigration a...
# 3   3AM immigration queues at Bangalore Airport. I...
# 4   May 23, 2022 — Scenes in immigration in the Be...
# ..                                                ...
# 94  Entertainment & Recreation Bangalore ravikumar...
# 95  May 16, 2018 — #India #Bengaluru #Bellandur #L...
# 96  Feb 9, 2018 — ... AIRPORT(http://taal.co.in) w...
# 97  The immigration officer at the Ahmd airport no...
# 98  (chennai - Bangalore 6E6137). I ... The great ...
#
#                                             highlighs
# 0           ['BLR Airport', 'Immigration', 'airport']
# 1                ['Immigration', 'Bengaluru Airport']
# 2   ['immigration', 'Bengaluru International Airpo...
# 3                ['immigration', 'Bangalore Airport']
# ...

# %%
df.to_excel('/Users/harshith/Desktop/untitled folder 2/interns1_new.xlsx',index=False)
